# %%
# FABRIC Configuration
SLICE_NAME = "bgp_sec_test"
SITE_NAME = "WASH"
MEAS_ADD = False

# Folded-Clos Configuration
PORTS_PER_DEVICE = 4
NUMBER_OF_TIERS = 2
NETWORK_NODE_PREFIXES = "T,S,L"
COMPUTE_NODE_PREFIXES = "C"
SEC_NODE_PREFIX = "H"
SINGLE_COMPUTE_SUBNET = False
SOUTHBOUND_PORT_DENSITY = {1:1}
ADD_SEC_NODE = True
BGP_SCRIPTS_LOCATION = "/home/fabric/work/NShenoy/FABRIC-Automation-main/remote_scripts/bgp_scripts"
TEMPLATE_LOCATION = "/home/fabric/work/NShenoy/FABRIC-Automation-main/remote_scripts/frr_templates/frr_conf_bgp.mako"

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
    fablib.show_config()
    print (fablib.get_image_names())


except Exception as e:
    print(f"Exception: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
#       3 try:
#       4     fablib = fablib_manager()
#
# ModuleNotFoundError: No module named 'fabrictestbed_extensions'

# %% [markdown]
# ## <span style="color: #de4815"><b>Build a Graph of the Folded-Clos Topology</b></span>
#
# A custom library, ClosGenerator, is used to build a graph-representation of a folded-Clos topology. BGP-4 configuration is added as attributes to the nodes as the graph is being constructed.

# %%
from infra_scripts.bgp.ClosGenerator import *

topology = BGPDCNConfig(PORTS_PER_DEVICE,
                        NUMBER_OF_TIERS,
                        southboundPortsConfig=SOUTHBOUND_PORT_DENSITY,
                        singleComputeSubnet=SINGLE_COMPUTE_SUBNET,
                        addSecurityNode=ADD_SEC_NODE)
topology.buildGraph()
logFile = topology.jsonGraphInfo()

print("BGP configuration complete\n")
print(f"Folded-Clos topology details (Not considering port density changes and security node additions):\n{topology.getClosStats()}")
# Out:
# BGP configuration complete
#
# Folded-Clos topology details (Not considering port density changes and security node additions):
# Number of ToF Nodes: 2
# Number of physical servers: 8
# Number of networking nodes: 6
# Number of leaves: 4
# Number of Pods: 1

# %% [markdown]
# ## <span style="color: #de4815"><b>Prepare the BGP Configuration Template</b></span>
#
# This book uses the Mako template engine to populate BGP-related information into the default FRR configuration file (frr.conf). The per-node BGP configuration is contained in the graph structure built in the prior section.

# %%
from mako.template import Template

try:
    bgpTemplate = Template(filename=TEMPLATE_LOCATION)
    print("FRR-BGP configuration template loaded.")

except Exception as e:
    print(f"Exception: {e}")
# Out:
# FRR-BGP configuration template loaded.

# %% [markdown]
# ## <span style="color: #de4815"><b>Parse the folded-Clos Configuration and Create the Slice</b></span>

# %%
import os

# CONFIGURATION FOR BGP-SPEAKING LEAF AND SPINE NODES
def addBGPConfiguration(node, nodeInfo, topology, bgpTemplate):
    '''
    Prepare a node for the FRR BGP-4 implementation to be installed.
    '''

    # Store information about BGP-speaking neighbors to configure neighborship
    neighboringNodes = []

    # Find the node's BGP-speaking neighbors and determine their ASN as well as their IPv4 address used on the subnet shared by the nodes.
    for neighbor, addr in topology.getNodeAttribute(node, 'ipv4').items():
        if(topology.isNetworkNode(neighbor)):
            neighboringNodes.append({'asn':topology.getNodeAttribute(neighbor, 'ASN'), 'ip':topology.getNodeAttribute(neighbor, 'ipv4', node)})

    # In addition to storing neighbor information, store any compute subnets that the node must advertise to neighbors (leaf's only).
    nodeTemplate = {'neighbors':neighboringNodes, 'bgp_asn': topology.getNodeAttribute(node, 'ASN'), 'networks': topology.getNodeAttribute(node, 'advertise')}

    # Process the stored information and render a custom frr.conf.
    nodeBGPData = bgpTemplate.render(**nodeTemplate)

    # Add FABRIC post-boot tasks to get the node ready for FRR installation
    nodeInfo.add_post_boot_upload_directory(BGP_SCRIPTS_LOCATION,'.')
    nodeInfo.add_post_boot_execute(f'sudo echo -e "{nodeBGPData}" > bgp_scripts/frr.conf')
    nodeInfo.add_post_boot_execute('sudo chmod +x /home/rocky/bgp_scripts/*.sh')

    return

# CONFIGURATION FOR NON-BGP-SPEAKING COMPUTE NODES
def addComputeConfiguration(nodeInfo):
    '''
    Prepare a node for traffic testing.
    '''
    nodeInfo.add_post_boot_upload_directory(BGP_SCRIPTS_LOCATION,'.')
    nodeInfo.add_post_boot_execute('sudo chmod +x /home/rocky/bgp_scripts/*.sh') # added sudo to the front of both of them and added all *.sh to execute

    return

# Create the slice
slice = fablib.new_slice(name=SLICE_NAME)

addedNodes = {} # Visited nodes structure, format = name : nodeInfo

# Add slice-specific information to the log file
logFile.update({"name": SLICE_NAME, "site": SITE_NAME, "meas": MEAS_ADD})

# Iterate over each network in the topology and configure each interface connected to the network, and the network itself.
for networkInfo in topology.iterNetwork(fabricFormating=True):
    networkIntfs = [] # Interfaces to be added to the network.
    network = networkInfo[0] # A tuple containing the nodes on the network.
    networkName = networkInfo[1] # The FABRIC network name.

    print(f"Configuring network: {network}")

    # For each node in a given IPv4 subnet within the folded-Clos topology.
    for node in network:
        # If the node has not yet been visited, provide it with the appropriate configuration.
        if(node not in addedNodes):
            # Add the node to the FABRIC slice.
            if(node.startswith(SEC_NODE_PREFIX)):
                nodeInfo = slice.add_node(name=node, cores=4, ram=4, disk=80, image='default_kali', site=SITE_NAME)
            else:
                nodeInfo = slice.add_node(name=node, cores=1, ram=4, image='default_rocky_8', site=SITE_NAME)

            # If the node is a non-compute node, it needs FRR-BGP configuration instructions.
            if(topology.isNetworkNode(node)):
                addBGPConfiguration(node, nodeInfo, topology, bgpTemplate)
            else:
                addComputeConfiguration(nodeInfo)

            addedNodes[node] = nodeInfo
            print(f"\tAdded node {node} to the slice.")

        else:
            print(f"\tAlready added node {node} to the slice.")

        # Create a name for the node's interface connected to this network and add it to the FABRIC slice.
        intfName = topology.generateFabricIntfName(node, network)
        netIntf = addedNodes[node].add_component(model='NIC_Basic', name=intfName).get_interfaces()[0]
        networkIntfs.append(netIntf)

    # Add the network to the FABRIC slice.
    slice.add_l2network(name=networkName, interfaces=networkIntfs, type="L2Bridge")
    print(f"\tAdded network {network}")
# Out:
# Configuring network: ('T-1', 'L-1')
# 	Added node T-1 to the slice.
# 	Added node L-1 to the slice.
# 	Added network ('T-1', 'L-1')
# Configuring network: ('T-1', 'H-1')
# 	Already added node T-1 to the slice.
# 	Added node H-1 to the slice.
# 	Added network ('T-1', 'H-1')
# Configuring network: ('T-1', 'L-2')
# 	Already added node T-1 to the slice.
# 	Added node L-2 to the slice.
# 	Added network ('T-1', 'L-2')
# Configuring network: ('T-1', 'L-3')
# 	Already added node T-1 to the slice.
# 	Added node L-3 to the slice.
# 	Added network ('T-1', 'L-3')
# Configuring network: ('T-1', 'L-4')
# 	Already added node T-1 to the slice.
# 	Added node L-4 to the slice.
# 	Added network ('T-1', 'L-4')
# Configuring network: ('L-1', 'T-2')
# 	Already added node L-1 to the slice.
# 	Added node T-2 to the slice.
# 	Added network ('L-1', 'T-2')
# Configuring network: ('L-1', 'C-1-1')
# 	Already added node L-1 to the slice.
# 	Added node C-1-1 to the slice.
# 	Added network ('L-1', 'C-1-1')
# Configuring network: ('L-2', 'T-2')
# 	Already added node L-2 to the slice.
# 	Already added node T-2 to the slice.
# 	Added network ('L-2', 'T-2')
# Configuring network: ('L-2', 'C-2-1')
# 	Already added node L-2 to the slice.
# 	Added node C-2-1 to the slice.
# 	Added network ('L-2', 'C-2-1')
# Configuring network: ('L-3', 'T-2')
# 	Already added node L-3 to the slice.
# 	Already added node T-2 to the slice.
# 	Added network ('L-3', 'T-2')
# Configuring network: ('L-3', 'C-3-1')
# 	Already added node L-3 to the slice.
# 	Added node C-3-1 to the slice.
# 	Added network ('L-3', 'C-3-1')
# Configuring network: ('L-4', 'T-2')
# 	Already added node L-4 to the slice.
# 	Already added node T-2 to the slice.
# 	Added network ('L-4', 'T-2')
# Configuring network: ('L-4', 'C-4-1')
# 	Already added node L-4 to the slice.
# 	Added node C-4-1 to the slice.
# 	Added network ('L-4', 'C-4-1')

# %% [markdown]
# ## <span style="color: #de4815"><b>Add a Measurement Node (Optional)</b></span>

# %%
if(MEAS_ADD):
    import mflib
    print(f"MFLib version  {mflib.__version__} " )

    from mflib.mflib import MFLib

    # Add measurement node to topology using static method.
    MFLib.addMeasNode(slice, disk=100, image='docker_ubuntu_20', site=SITE_NAME)
    print("Measurement node added.")

else:
    print("No measurement node added.")

# %% [markdown]
# ## <span style="color: #de4815"><b>Submit the Slice</b></span>

# %%
# %%time
import json

try:
    # Submit Slice Request
    print(f'Submitting the new slice, "{SLICE_NAME}"...')
    slice.submit()
    print(f'{SLICE_NAME} creation done.')

except Exception as e:
    print(f"Slice Fail: {e}")
    traceback.print_exc()
# Out:
# Retry: 14, Time: 565 sec
# <style type="text/css">
# #T_10f47 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_10f47 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_10f47 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_10f47_row0_col0, #T_10f47_row0_col1, #T_10f47_row1_col0, #T_10f47_row1_col1, #T_10f47_row2_col0, #T_10f47_row2_col1, #T_10f47_row3_col0, #T_10f47_row3_col1, #T_10f47_row4_col0, #T_10f47_row4_col1, #T_10f47_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_10f47_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_10f47">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_10f47_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_10f47_row0_col1" class="data row0 col1" >9bf97198-7417-47ab-94c9-290e328051a3</td>
#     </tr>
#     <tr>
#       <td id="T_10f47_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_10f47_row1_col1" class="data row1 col1" >bgp_sec_test</td>
#     </tr>
#     <tr>
#       <td id="T_10f47_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_10f47_row2_col1" class="data row2 col1" >2024-09-06 13:57:41 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_10f47_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_10f47_row3_col1" class="data row3 col1" >2024-09-05 13:57:41 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_10f47_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_10f47_row4_col1" class="data row4 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_10f47_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_10f47_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3dbf4 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3dbf4 th {
#   text-align: left;
# }
# #T_3dbf4 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3dbf4 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3dbf4 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3dbf4_row0_col0, #T_3dbf4_row0_col1, #T_3dbf4_row0_col2, #T_3dbf4_row0_col3, #T_3dbf4_row0_col4, #T_3dbf4_row0_col5, #T_3dbf4_row0_col6, #T_3dbf4_row0_col7, #T_3dbf4_row0_col8, #T_3dbf4_row0_col9, #T_3dbf4_row0_col10, #T_3dbf4_row0_col13, #T_3dbf4_row0_col14, #T_3dbf4_row0_col15, #T_3dbf4_row1_col0, #T_3dbf4_row1_col1, #T_3dbf4_row1_col2, #T_3dbf4_row1_col3, #T_3dbf4_row1_col4, #T_3dbf4_row1_col5, #T_3dbf4_row1_col6, #T_3dbf4_row1_col7, #T_3dbf4_row1_col8, #T_3dbf4_row1_col9, #T_3dbf4_row1_col10, #T_3dbf4_row1_col13, #T_3dbf4_row1_col14, #T_3dbf4_row1_col15, #T_3dbf4_row2_col0, #T_3dbf4_row2_col1, #T_3dbf4_row2_col2, #T_3dbf4_row2_col3, #T_3dbf4_row2_col4, #T_3dbf4_row2_col5, #T_3dbf4_row2_col6, #T_3dbf4_row2_col7, #T_3dbf4_row2_col8, #T_3dbf4_row2_col9, #T_3dbf4_row2_col10, #T_3dbf4_row2_col13, #T_3dbf4_row2_col14, #T_3dbf4_row2_col15, #T_3dbf4_row3_col0, #T_3dbf4_row3_col1, #T_3dbf4_row3_col2, #T_3dbf4_row3_col3, #T_3dbf4_row3_col4, #T_3dbf4_row3_col5, #T_3dbf4_row3_col6, #T_3dbf4_row3_col7, #T_3dbf4_row3_col8, #T_3dbf4_row3_col9, #T_3dbf4_row3_col10, #T_3dbf4_row3_col13, #T_3dbf4_row3_col14, #T_3dbf4_row3_col15, #T_3dbf4_row4_col0, #T_3dbf4_row4_col1, #T_3dbf4_row4_col2, #T_3dbf4_row4_col3, #T_3dbf4_row4_col4, #T_3dbf4_row4_col5, #T_3dbf4_row4_col6, #T_3dbf4_row4_col7, #T_3dbf4_row4_col8, #T_3dbf4_row4_col9, #T_3dbf4_row4_col10, #T_3dbf4_row4_col13, #T_3dbf4_row4_col14, #T_3dbf4_row4_col15, #T_3dbf4_row5_col0, #T_3dbf4_row5_col1, #T_3dbf4_row5_col2, #T_3dbf4_row5_col3, #T_3dbf4_row5_col4, #T_3dbf4_row5_col5, #T_3dbf4_row5_col6, #T_3dbf4_row5_col7, #T_3dbf4_row5_col8, #T_3dbf4_row5_col9, #T_3dbf4_row5_col10, #T_3dbf4_row5_col13, #T_3dbf4_row5_col14, #T_3dbf4_row5_col15, #T_3dbf4_row6_col0, #T_3dbf4_row6_col1, #T_3dbf4_row6_col2, #T_3dbf4_row6_col3, #T_3dbf4_row6_col4, #T_3dbf4_row6_col5, #T_3dbf4_row6_col6, #T_3dbf4_row6_col7, #T_3dbf4_row6_col8, #T_3dbf4_row6_col9, #T_3dbf4_row6_col10, #T_3dbf4_row6_col13, #T_3dbf4_row6_col14, #T_3dbf4_row6_col15, #T_3dbf4_row7_col0, #T_3dbf4_row7_col1, #T_3dbf4_row7_col2, #T_3dbf4_row7_col3, #T_3dbf4_row7_col4, #T_3dbf4_row7_col5, #T_3dbf4_row7_col6, #T_3dbf4_row7_col7, #T_3dbf4_row7_col8, #T_3dbf4_row7_col9, #T_3dbf4_row7_col10, #T_3dbf4_row7_col13, #T_3dbf4_row7_col14, #T_3dbf4_row7_col15, #T_3dbf4_row8_col0, #T_3dbf4_row8_col1, #T_3dbf4_row8_col2, #T_3dbf4_row8_col3, #T_3dbf4_row8_col4, #T_3dbf4_row8_col5, #T_3dbf4_row8_col6, #T_3dbf4_row8_col7, #T_3dbf4_row8_col8, #T_3dbf4_row8_col9, #T_3dbf4_row8_col10, #T_3dbf4_row8_col13, #T_3dbf4_row8_col14, #T_3dbf4_row8_col15, #T_3dbf4_row9_col0, #T_3dbf4_row9_col1, #T_3dbf4_row9_col2, #T_3dbf4_row9_col3, #T_3dbf4_row9_col4, #T_3dbf4_row9_col5, #T_3dbf4_row9_col6, #T_3dbf4_row9_col7, #T_3dbf4_row9_col8, #T_3dbf4_row9_col9, #T_3dbf4_row9_col10, #T_3dbf4_row9_col13, #T_3dbf4_row9_col14, #T_3dbf4_row9_col15, #T_3dbf4_row10_col0, #T_3dbf4_row10_col1, #T_3dbf4_row10_col2, #T_3dbf4_row10_col3, #T_3dbf4_row10_col4, #T_3dbf4_row10_col5, #T_3dbf4_row10_col6, #T_3dbf4_row10_col7, #T_3dbf4_row10_col8, #T_3dbf4_row10_col9, #T_3dbf4_row10_col10, #T_3dbf4_row10_col13, #T_3dbf4_row10_col14, #T_3dbf4_row10_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_3dbf4_row0_col11, #T_3dbf4_row1_col11, #T_3dbf4_row2_col11, #T_3dbf4_row3_col11, #T_3dbf4_row4_col11, #T_3dbf4_row5_col11, #T_3dbf4_row6_col11, #T_3dbf4_row7_col11, #T_3dbf4_row8_col11, #T_3dbf4_row9_col11, #T_3dbf4_row10_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_3dbf4_row0_col12, #T_3dbf4_row1_col12, #T_3dbf4_row2_col12, #T_3dbf4_row3_col12, #T_3dbf4_row4_col12, #T_3dbf4_row5_col12, #T_3dbf4_row6_col12, #T_3dbf4_row7_col12, #T_3dbf4_row8_col12, #T_3dbf4_row9_col12, #T_3dbf4_row10_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_3dbf4">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_3dbf4_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_3dbf4_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_3dbf4_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_3dbf4_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_3dbf4_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_3dbf4_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_3dbf4_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_3dbf4_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_3dbf4_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_3dbf4_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_3dbf4_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_3dbf4_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_3dbf4_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_3dbf4_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_3dbf4_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_3dbf4_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3dbf4_row0_col0" class="data row0 col0" >cfd430c9-3470-43a5-b3c4-057cbc75510d</td>
#       <td id="T_3dbf4_row0_col1" class="data row0 col1" >C-1-1</td>
#       <td id="T_3dbf4_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_3dbf4_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_3dbf4_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_3dbf4_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_3dbf4_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_3dbf4_row0_col7" class="data row0 col7" >wash-w3.fabric-testbed.net</td>
#       <td id="T_3dbf4_row0_col8" class="data row0 col8" >WASH</td>
#       <td id="T_3dbf4_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_3dbf4_row0_col10" class="data row0 col10" >2001:400:a100:3020:f816:3eff:fe3d:b271</td>
#       <td id="T_3dbf4_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_3dbf4_row0_col12" class="data row0 col12" ></td>
#       <td id="T_3dbf4_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/SliceKey -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3020:f816:3eff:fe3d:b271</td>
#       <td id="T_3dbf4_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/SliceKey.pub</td>
#       <td id="T_3dbf4_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/SliceKey</td>
#     </tr>
#     <tr>
#       <td id="T_3dbf4_row1_col0" class="data row1 col0" >413c7c93-31a1-4357-92f5-522038abd052</td>
#       <td id="T_3dbf4_row1_col1" class="data row1 col1" >C-2-1</td>
#       <td id="T_3dbf4_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_3dbf4_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_3dbf4_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_3dbf4_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_3dbf4_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_3dbf4_row1_col7" class="data row1 col7" >wash-w1.fabric-testbed.net</td>
#       <td id="T_3dbf4_row1_col8" class="data row1 col8" >WASH</td>
#       <td id="T_3dbf4_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_3dbf4_row1_col10" class="data row1 col10" >2001:400:a100:3020:f816:3eff:fe09:dd6e</td>
#       <td id="T_3dbf4_row1_col11" clas
# <style type="text/css">
# #T_4b7cb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_4b7cb th {
#   text-align: left;
# }
# #T_4b7cb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4b7cb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4b7cb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4b7cb_row0_col0, #T_4b7cb_row0_col1, #T_4b7cb_row0_col2, #T_4b7cb_row0_col3, #T_4b7cb_row0_col4, #T_4b7cb_row0_col5, #T_4b7cb_row0_col6, #T_4b7cb_row1_col0, #T_4b7cb_row1_col1, #T_4b7cb_row1_col2, #T_4b7cb_row1_col3, #T_4b7cb_row1_col4, #T_4b7cb_row1_col5, #T_4b7cb_row1_col6, #T_4b7cb_row2_col0, #T_4b7cb_row2_col1, #T_4b7cb_row2_col2, #T_4b7cb_row2_col3, #T_4b7cb_row2_col4, #T_4b7cb_row2_col5, #T_4b7cb_row2_col6, #T_4b7cb_row3_col0, #T_4b7cb_row3_col1, #T_4b7cb_row3_col2, #T_4b7cb_row3_col3, #T_4b7cb_row3_col4, #T_4b7cb_row3_col5, #T_4b7cb_row3_col6, #T_4b7cb_row4_col0, #T_4b7cb_row4_col1, #T_4b7cb_row4_col2, #T_4b7cb_row4_col3, #T_4b7cb_row4_col4, #T_4b7cb_row4_col5, #T_4b7cb_row4_col6, #T_4b7cb_row5_col0, #T_4b7cb_row5_col1, #T_4b7cb_row5_col2, #T_4b7cb_row5_col3, #T_4b7cb_row5_col4, #T_4b7cb_row5_col5, #T_4b7cb_row5_col6, #T_4b7cb_row6_col0, #T_4b7cb_row6_col1, #T_4b7cb_row6_col2, #T_4b7cb_row6_col3, #T_4b7cb_row6_col4, #T_4b7cb_row6_col5, #T_4b7cb_row6_col6, #T_4b7cb_row7_col0, #T_4b7cb_row7_col1, #T_4b7cb_row7_col2, #T_4b7cb_row7_col3, #T_4b7cb_row7_col4, #T_4b7cb_row7_col5, #T_4b7cb_row7_col6, #T_4b7cb_row8_col0, #T_4b7cb_row8_col1, #T_4b7cb_row8_col2, #T_4b7cb_row8_col3, #T_4b7cb_row8_col4, #T_4b7cb_row8_col5, #T_4b7cb_row8_col6, #T_4b7cb_row9_col0, #T_4b7cb_row9_col1, #T_4b7cb_row9_col2, #T_4b7cb_row9_col3, #T_4b7cb_row9_col4, #T_4b7cb_row9_col5, #T_4b7cb_row9_col6, #T_4b7cb_row10_col0, #T_4b7cb_row10_col1, #T_4b7cb_row10_col2, #T_4b7cb_row10_col3, #T_4b7cb_row10_col4, #T_4b7cb_row10_col5, #T_4b7cb_row10_col6, #T_4b7cb_row11_col0, #T_4b7cb_row11_col1, #T_4b7cb_row11_col2, #T_4b7cb_row11_col3, #T_4b7cb_row11_col4, #T_4b7cb_row11_col5, #T_4b7cb_row11_col6, #T_4b7cb_row12_col0, #T_4b7cb_row12_col1, #T_4b7cb_row12_col2, #T_4b7cb_row12_col3, #T_4b7cb_row12_col4, #T_4b7cb_row12_col5, #T_4b7cb_row12_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_4b7cb_row0_col7, #T_4b7cb_row1_col7, #T_4b7cb_row2_col7, #T_4b7cb_row3_col7, #T_4b7cb_row4_col7, #T_4b7cb_row5_col7, #T_4b7cb_row6_col7, #T_4b7cb_row7_col7, #T_4b7cb_row8_col7, #T_4b7cb_row9_col7, #T_4b7cb_row10_col7, #T_4b7cb_row12_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_4b7cb_row0_col8, #T_4b7cb_row1_col8, #T_4b7cb_row2_col8, #T_4b7cb_row3_col8, #T_4b7cb_row4_col8, #T_4b7cb_row5_col8, #T_4b7cb_row6_col8, #T_4b7cb_row7_col8, #T_4b7cb_row8_col8, #T_4b7cb_row9_col8, #T_4b7cb_row10_col8, #T_4b7cb_row11_col8, #T_4b7cb_row12_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_4b7cb_row11_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffffbe;
# }
# </style>
# <table id="T_4b7cb">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_4b7cb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_4b7cb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_4b7cb_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_4b7cb_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_4b7cb_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_4b7cb_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_4b7cb_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_4b7cb_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_4b7cb_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4b7cb_row0_col0" class="data row0 col0" >b6f255f4-708b-4cc7-a4f3-761297255cb0</td>
#       <td id="T_4b7cb_row0_col1" class="data row0 col1" >core-T-1-L-1</td>
#       <td id="T_4b7cb_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_4b7cb_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row0_col4" class="data row0 col4" >WASH</td>
#       <td id="T_4b7cb_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_4b7cb_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_4b7cb_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_4b7cb_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row1_col0" class="data row1 col0" >d3871ffa-d2a4-46ea-9043-2aabd5f93a8e</td>
#       <td id="T_4b7cb_row1_col1" class="data row1 col1" >core-T-1-L-2</td>
#       <td id="T_4b7cb_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_4b7cb_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row1_col4" class="data row1 col4" >WASH</td>
#       <td id="T_4b7cb_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_4b7cb_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_4b7cb_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_4b7cb_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row2_col0" class="data row2 col0" >7e38e6a4-ac33-49bf-a4ee-64f1030bd82b</td>
#       <td id="T_4b7cb_row2_col1" class="data row2 col1" >core-T-1-L-3</td>
#       <td id="T_4b7cb_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_4b7cb_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row2_col4" class="data row2 col4" >WASH</td>
#       <td id="T_4b7cb_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_4b7cb_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_4b7cb_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_4b7cb_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row3_col0" class="data row3 col0" >ce1b4b61-e477-48e2-87ae-15c7dcefac08</td>
#       <td id="T_4b7cb_row3_col1" class="data row3 col1" >core-T-1-L-4</td>
#       <td id="T_4b7cb_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_4b7cb_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row3_col4" class="data row3 col4" >WASH</td>
#       <td id="T_4b7cb_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_4b7cb_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_4b7cb_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_4b7cb_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row4_col0" class="data row4 col0" >9584c4d5-6dfe-429f-9bda-3e15b21b6114</td>
#       <td id="T_4b7cb_row4_col1" class="data row4 col1" >core-T-2-L-1</td>
#       <td id="T_4b7cb_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_4b7cb_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row4_col4" class="data row4 col4" >WASH</td>
#       <td id="T_4b7cb_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_4b7cb_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_4b7cb_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_4b7cb_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row5_col0" class="data row5 col0" >1094dd8e-009e-49f3-8fa9-556bf6f36c7c</td>
#       <td id="T_4b7cb_row5_col1" class="data row5 col1" >core-T-2-L-2</td>
#       <td id="T_4b7cb_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_4b7cb_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_4b7cb_row5_col4" class="data row5 col4" >WASH</td>
#       <td id="T_4b7cb_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_4b7cb_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_4b7cb_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_4b7cb_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_4b7cb_row6_col0" c
# <style type="text/css">
# #T_10814 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_10814 th {
#   text-align: left;
# }
# #T_10814 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_10814 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_10814 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_10814_row0_col0, #T_10814_row0_col1, #T_10814_row0_col2, #T_10814_row0_col3, #T_10814_row0_col4, #T_10814_row0_col5, #T_10814_row0_col6, #T_10814_row0_col7, #T_10814_row0_col8, #T_10814_row0_col9, #T_10814_row0_col10, #T_10814_row0_col11, #T_10814_row0_col12, #T_10814_row1_col0, #T_10814_row1_col1, #T_10814_row1_col2, #T_10814_row1_col3, #T_10814_row1_col4, #T_10814_row1_col5, #T_10814_row1_col6, #T_10814_row1_col7, #T_10814_row1_col8, #T_10814_row1_col9, #T_10814_row1_col10, #T_10814_row1_col11, #T_10814_row1_col12, #T_10814_row2_col0, #T_10814_row2_col1, #T_10814_row2_col2, #T_10814_row2_col3, #T_10814_row2_col4, #T_10814_row2_col5, #T_10814_row2_col6, #T_10814_row2_col7, #T_10814_row2_col8, #T_10814_row2_col9, #T_10814_row2_col10, #T_10814_row2_col11, #T_10814_row2_col12, #T_10814_row3_col0, #T_10814_row3_col1, #T_10814_row3_col2, #T_10814_row3_col3, #T_10814_row3_col4, #T_10814_row3_col5, #T_10814_row3_col6, #T_10814_row3_col7, #T_10814_row3_col8, #T_10814_row3_col9, #T_10814_row3_col10, #T_10814_row3_col11, #T_10814_row3_col12, #T_10814_row4_col0, #T_10814_row4_col1, #T_10814_row4_col2, #T_10814_row4_col3, #T_10814_row4_col4, #T_10814_row4_col5, #T_10814_row4_col6, #T_10814_row4_col7, #T_10814_row4_col8, #T_10814_row4_col9, #T_10814_row4_col10, #T_10814_row4_col11, #T_10814_row4_col12, #T_10814_row5_col0, #T_10814_row5_col1, #T_10814_row5_col2, #T_10814_row5_col3, #T_10814_row5_col4, #T_10814_row5_col5, #T_10814_row5_col6, #T_10814_row5_col7, #T_10814_row5_col8, #T_10814_row5_col9, #T_10814_row5_col10, #T_10814_row5_col11, #T_10814_row5_col12, #T_10814_row6_col0, #T_10814_row6_col1, #T_10814_row6_col2, #T_10814_row6_col3, #T_10814_row6_col4, #T_10814_row6_col5, #T_10814_row6_col6, #T_10814_row6_col7, #T_10814_row6_col8, #T_10814_row6_col9, #T_10814_row6_col10, #T_10814_row6_col11, #T_10814_row6_col12, #T_10814_row7_col0, #T_10814_row7_col1, #T_10814_row7_col2, #T_10814_row7_col3, #T_10814_row7_col4, #T_10814_row7_col5, #T_10814_row7_col6, #T_10814_row7_col7, #T_10814_row7_col8, #T_10814_row7_col9, #T_10814_row7_col10, #T_10814_row7_col11, #T_10814_row7_col12, #T_10814_row8_col0, #T_10814_row8_col1, #T_10814_row8_col2, #T_10814_row8_col3, #T_10814_row8_col4, #T_10814_row8_col5, #T_10814_row8_col6, #T_10814_row8_col7, #T_10814_row8_col8, #T_10814_row8_col9, #T_10814_row8_col10, #T_10814_row8_col11, #T_10814_row8_col12, #T_10814_row9_col0, #T_10814_row9_col1, #T_10814_row9_col2, #T_10814_row9_col3, #T_10814_row9_col4, #T_10814_row9_col5, #T_10814_row9_col6, #T_10814_row9_col7, #T_10814_row9_col8, #T_10814_row9_col9, #T_10814_row9_col10, #T_10814_row9_col11, #T_10814_row9_col12, #T_10814_row10_col0, #T_10814_row10_col1, #T_10814_row10_col2, #T_10814_row10_col3, #T_10814_row10_col4, #T_10814_row10_col5, #T_10814_row10_col6, #T_10814_row10_col7, #T_10814_row10_col8, #T_10814_row10_col9, #T_10814_row10_col10, #T_10814_row10_col11, #T_10814_row10_col12, #T_10814_row11_col0, #T_10814_row11_col1, #T_10814_row11_col2, #T_10814_row11_col3, #T_10814_row11_col4, #T_10814_row11_col5, #T_10814_row11_col6, #T_10814_row11_col7, #T_10814_row11_col8, #T_10814_row11_col9, #T_10814_row11_col10, #T_10814_row11_col11, #T_10814_row11_col12, #T_10814_row12_col0, #T_10814_row12_col1, #T_10814_row12_col2, #T_10814_row12_col3, #T_10814_row12_col4, #T_10814_row12_col5, #T_10814_row12_col6, #T_10814_row12_col7, #T_10814_row12_col8, #T_10814_row12_col9, #T_10814_row12_col10, #T_10814_row12_col11, #T_10814_row12_col12, #T_10814_row13_col0, #T_10814_row13_col1, #T_10814_row13_col2, #T_10814_row13_col3, #T_10814_row13_col4, #T_10814_row13_col5, #T_10814_row13_col6, #T_10814_row13_col7, #T_10814_row13_col8, #T_10814_row13_col9, #T_10814_row13_col10, #T_10814_row13_col11, #T_10814_row13_col12, #T_10814_row14_col0, #T_10814_row14_col1, #T_10814_row14_col2, #T_10814_row14_col3, #T_10814_row14_col4, #T_10814_row14_col5, #T_10814_row14_col6, #T_10814_row14_col7, #T_10814_row14_col8, #T_10814_row14_col9, #T_10814_row14_col10, #T_10814_row14_col11, #T_10814_row ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_10814">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_10814_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_10814_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_10814_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_10814_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_10814_level0_col4" class="col_heading level0 col4" >Bandwidth</th
# Time to print interfaces 639 seconds
# bgp_sec_test creation done.
# CPU times: user 1min 18s, sys: 4.07 s, total: 1min 22s
# Wall time: 10min 52s

# %% [markdown]
# ## <span style="color: #de4815"><b>Initalize the Measurement Framework (Optional)</b></span>
#
# This step both initalizes and instrumentizes the Measurement framework to use Prometheus and Grafana. If ELK is desired, modifications to the cell need to be made.

# %%
if(MEAS_ADD):
    mf = MFLib(SLICE_NAME) # Initalize
    instrumetize_results = mf.instrumentize( ["prometheus"] ) # Instrumentize

    # Grafana SSH Tunnel Command
    print(mf.grafana_tunnel)
    print(f"Browse to https://localhost:{mf.grafana_tunnel_local_port}/grafana/dashboards?query=%2A")

# %% [markdown]
# ## <span style="color: #de4815"><b>Provide Initial Configuration to Nodes</b></span>
#
# If the node is a core (BGP-speaking) node, it will have FRR installed and the BGP daemon (bgpd) turned on as well as configured.
#
# If the node is an edge (non-BGP-speaking) node, it will have the traffic generator code installed.

# %%
SLICE_NAME = "bgp_sec_test"
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
    fablib.show_config()

except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_a1dca tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a1dca tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a1dca caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_a1dca_row0_col0, #T_a1dca_row0_col1, #T_a1dca_row1_col0, #T_a1dca_row1_col1, #T_a1dca_row2_col0, #T_a1dca_row2_col1, #T_a1dca_row3_col0, #T_a1dca_row3_col1, #T_a1dca_row4_col0, #T_a1dca_row4_col1, #T_a1dca_row5_col0, #T_a1dca_row5_col1, #T_a1dca_row6_col0, #T_a1dca_row6_col1, #T_a1dca_row7_col0, #T_a1dca_row7_col1, #T_a1dca_row8_col0, #T_a1dca_row8_col1, #T_a1dca_row9_col0, #T_a1dca_row9_col1, #T_a1dca_row10_col0, #T_a1dca_row10_col1, #T_a1dca_row11_col0, #T_a1dca_row11_col1, #T_a1dca_row12_col0, #T_a1dca_row12_col1, #T_a1dca_row13_col0, #T_a1dca_row13_col1, #T_a1dca_row14_col0, #T_a1dca_row14_col1, #T_a1dca_row15_col0, #T_a1dca_row15_col1, #T_a1dca_row16_col0, #T_a1dca_row16_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_a1dca">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a1dca_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_a1dca_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_a1dca_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row2_col0" class="data row2 col0" >Project ID</td>
#       <td id="T_a1dca_row2_col1" class="data row2 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_a1dca_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row4_col0" class="data row4 col0" >Bastion Host</td>
#       <td id="T_a1dca_row4_col1" class="data row4 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row5_col0" class="data row5 col0" >Bastion Username</td>
#       <td id="T_a1dca_row5_col1" class="data row5 col1" >nxsvks_0000031803</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row6_col0" class="data row6 col0" >Bastion Private Key File</td>
#       <td id="T_a1dca_row6_col1" class="data row6 col1" >/home/fabric/work/fabric_config/BastKey</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row7_col0" class="data row7 col0" >Slice Private Key File</td>
#       <td id="T_a1dca_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/SliceKey</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_a1dca_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/SliceKey.pub</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row9_col0" class="data row9 col0" >Log File</td>
#       <td id="T_a1dca_row9_col1" class="data row9 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row10_col0" class="data row10 col0" >Log Level</td>
#       <td id="T_a1dca_row10_col1" class="data row10 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_a1dca_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_a1dca_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_a1dca_row13_col1" class="data row13 col1" >1.7.3</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row14_col0" class="data row14 col0" >Data directory</td>
#       <td id="T_a1dca_row14_col1" class="data row14 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row15_col0" class="data row15 col0" >Core API</td>
#       <td id="T_a1dca_row15_col1" class="data row15 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a1dca_row16_col0" class="data row16 col0" >Bastion SSH Config File</td>
#       <td id="T_a1dca_row16_col1" class="data row16 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#   </tbody>
# </table>

# %%
from FabUtils import FabOrchestrator

try:
    manager = FabOrchestrator(SLICE_NAME)

except Exception as e:
    print(f"Exception: {e}")
# Out:
# Slice name: bgp_sec_test
# Slice and nodes were acquired successfully.

# %%
# Commands to execute the bash scripts configuring the nodes
coreNodeConfig = "./bgp_scripts/init_bgp.sh"
edgeNodeConfig = "./bgp_scripts/init_compute.sh"

# Configure core (BGP-speaking) nodes
manager.executeCommandsParallel(coreNodeConfig, prefixList=NETWORK_NODE_PREFIXES)

# Configure edge (non-BGP-speaking) nodes
manager.executeCommandsParallel(edgeNodeConfig, prefixList=COMPUTE_NODE_PREFIXES)

# %% [markdown]
# ## <span style="color: #de4815"><b>Add IPv4 Addressing to All Nodes</b></span>
#
# This system utilizes the addressing provided by the ClosGenerator module:
#
# * 192.168.0.0/16 is the compute supernet. All compute subnets are given a /24 subnet. Compute devices are given lower addresses (ex: .1) and the leaf node is given a high address (ex: .254)
#
# * 172.16.0.0/12 is the core supernet. All core subnets are given a /24 subnet. Both devices are given lower addresses.

# %%
SLICE_NAME = "bgp_sec_test" #provide slicename
slice = fablib.get_slice(name=SLICE_NAME)
#for node in slice.get_nodes(): # nirmala added this because the nodes did not have a route afetr we stopped the NM service
#    node.execute("sudo systemctl start NetworkManager.service")
slice.show()
slice.list_nodes()
slice.list_networks()
# Out:
# <style type="text/css">
# #T_a7e66 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a7e66 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a7e66 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_a7e66_row0_col0, #T_a7e66_row0_col1, #T_a7e66_row1_col0, #T_a7e66_row1_col1, #T_a7e66_row2_col0, #T_a7e66_row2_col1, #T_a7e66_row3_col0, #T_a7e66_row3_col1, #T_a7e66_row4_col0, #T_a7e66_row4_col1, #T_a7e66_row5_col0, #T_a7e66_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_a7e66">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7e66_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_a7e66_row0_col1" class="data row0 col1" >9bf97198-7417-47ab-94c9-290e328051a3</td>
#     </tr>
#     <tr>
#       <td id="T_a7e66_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_a7e66_row1_col1" class="data row1 col1" >bgp_sec_test</td>
#     </tr>
#     <tr>
#       <td id="T_a7e66_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_a7e66_row2_col1" class="data row2 col1" >2024-09-06 13:57:41 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_a7e66_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_a7e66_row3_col1" class="data row3 col1" >2024-09-05 13:57:41 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_a7e66_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_a7e66_row4_col1" class="data row4 col1" >787adfc9-d37e-42f2-8efe-8e32793e0bb8</td>
#     </tr>
#     <tr>
#       <td id="T_a7e66_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_a7e66_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_414bb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_414bb th {
#   text-align: left;
# }
# #T_414bb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_414bb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_414bb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_414bb_row0_col0, #T_414bb_row0_col1, #T_414bb_row0_col2, #T_414bb_row0_col3, #T_414bb_row0_col4, #T_414bb_row0_col5, #T_414bb_row0_col6, #T_414bb_row0_col7, #T_414bb_row0_col8, #T_414bb_row0_col9, #T_414bb_row0_col10, #T_414bb_row0_col11, #T_414bb_row0_col12, #T_414bb_row0_col13, #T_414bb_row0_col14, #T_414bb_row0_col15, #T_414bb_row1_col0, #T_414bb_row1_col1, #T_414bb_row1_col2, #T_414bb_row1_col3, #T_414bb_row1_col4, #T_414bb_row1_col5, #T_414bb_row1_col6, #T_414bb_row1_col7, #T_414bb_row1_col8, #T_414bb_row1_col9, #T_414bb_row1_col10, #T_414bb_row1_col11, #T_414bb_row1_col12, #T_414bb_row1_col13, #T_414bb_row1_col14, #T_414bb_row1_col15, #T_414bb_row2_col0, #T_414bb_row2_col1, #T_414bb_row2_col2, #T_414bb_row2_col3, #T_414bb_row2_col4, #T_414bb_row2_col5, #T_414bb_row2_col6, #T_414bb_row2_col7, #T_414bb_row2_col8, #T_414bb_row2_col9, #T_414bb_row2_col10, #T_414bb_row2_col11, #T_414bb_row2_col12, #T_414bb_row2_col13, #T_414bb_row2_col14, #T_414bb_row2_col15, #T_414bb_row3_col0, #T_414bb_row3_col1, #T_414bb_row3_col2, #T_414bb_row3_col3, #T_414bb_row3_col4, #T_414bb_row3_col5, #T_414bb_row3_col6, #T_414bb_row3_col7, #T_414bb_row3_col8, #T_414bb_row3_col9, #T_414bb_row3_col10, #T_414bb_row3_col11, #T_414bb_row3_col12, #T_414bb_row3_col13, #T_414bb_row3_col14, #T_414bb_row3_col15, #T_414bb_row4_col0, #T_414bb_row4_col1, #T_414bb_row4_col2, #T_414bb_row4_col3, #T_414bb_row4_col4, #T_414bb_row4_col5, #T_414bb_row4_col6, #T_414bb_row4_col7, #T_414bb_row4_col8, #T_414bb_row4_col9, #T_414bb_row4_col10, #T_414bb_row4_col11, #T_414bb_row4_col12, #T_414bb_row4_col13, #T_414bb_row4_col14, #T_414bb_row4_col15, #T_414bb_row5_col0, #T_414bb_row5_col1, #T_414bb_row5_col2, #T_414bb_row5_col3, #T_414bb_row5_col4, #T_414bb_row5_col5, #T_414bb_row5_col6, #T_414bb_row5_col7, #T_414bb_row5_col8, #T_414bb_row5_col9, #T_414bb_row5_col10, #T_414bb_row5_col11, #T_414bb_row5_col12, #T_414bb_row5_col13, #T_414bb_row5_col14, #T_414bb_row5_col15, #T_414bb_row6_col0, #T_414bb_row6_col1, #T_414bb_row6_col2, #T_414bb_row6_col3, #T_414bb_row6_col4, #T_414bb_row6_col5, #T_414bb_row6_col6, #T_414bb_row6_col7, #T_414bb_row6_col8, #T_414bb_row6_col9, #T_414bb_row6_col10, #T_414bb_row6_col11, #T_414bb_row6_col12, #T_414bb_row6_col13, #T_414bb_row6_col14, #T_414bb_row6_col15, #T_414bb_row7_col0, #T_414bb_row7_col1, #T_414bb_row7_col2, #T_414bb_row7_col3, #T_414bb_row7_col4, #T_414bb_row7_col5, #T_414bb_row7_col6, #T_414bb_row7_col7, #T_414bb_row7_col8, #T_414bb_row7_col9, #T_414bb_row7_col10, #T_414bb_row7_col11, #T_414bb_row7_col12, #T_414bb_row7_col13, #T_414bb_row7_col14, #T_414bb_row7_col15, #T_414bb_row8_col0, #T_414bb_row8_col1, #T_414bb_row8_col2, #T_414bb_row8_col3, #T_414bb_row8_col4, #T_414bb_row8_col5, #T_414bb_row8_col6, #T_414bb_row8_col7, #T_414bb_row8_col8, #T_414bb_row8_col9, #T_414bb_row8_col10, #T_414bb_row8_col11, #T_414bb_row8_col12, #T_414bb_row8_col13, #T_414bb_row8_col14, #T_414bb_row8_col15, #T_414bb_row9_col0, #T_414bb_row9_col1, #T_414bb_row9_col2, #T_414bb_row9_col3, #T_414bb_row9_col4, #T_414bb_row9_col5, #T_414bb_row9_col6, #T_414bb_row9_col7, #T_414bb_row9_col8, #T_414bb_row9_col9, #T_414bb_row9_col10, #T_414bb_row9_col11, #T_414bb_row9_col12, #T_414bb_row9_col13, #T_414bb_row9_col14, #T_414bb_row9_col15, #T_414bb_row10_col0, #T_414bb_row10_col1, #T_414bb_row10_col2, #T_414bb_row10_col3, #T_414bb_row10_col4, #T_414bb_row10_col5, #T_414bb_row10_col6, #T_414bb_row10_col7, #T_414bb_row10_col8, #T_414bb_row10_col9, #T_414bb_row10_col10, #T_414bb_row10_col11, #T_414bb_row10_col12, #T_414bb_row10_col13, #T_414bb_row10_col14, #T_414bb_row10_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_414bb">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_414bb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_414bb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_414bb_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_414bb_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_414bb_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_414bb_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_414bb_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_414bb_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_414bb_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_414bb_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_414bb_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_414bb_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_414bb_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_414bb_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_414bb_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_414bb_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_414bb_row0_col0" class="data row0 col0" >cfd430c9-3470-43a5-b3c4-057cbc75510d</td>
#       <td id="T_414bb_row0_col1" class="data row0 col1" >C-1-1</td>
#       <td id="T_414bb_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_414bb_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_414bb_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_414bb_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_414bb_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_414bb_row0_col7" class="data row0 col7" >wash-w3.fabric-testbed.net</td>
#       <td id="T_414bb_row0_col8" class="data row0 col8" >WASH</td>
#       <td id="T_414bb_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_414bb_row0_col10" class="data row0 col10" >2001:400:a100:3020:f816:3eff:fe3d:b271</td>
#       <td id="T_414bb_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_414bb_row0_col12" class="data row0 col12" ></td>
#       <td id="T_414bb_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/SliceKey -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3020:f816:3eff:fe3d:b271</td>
#       <td id="T_414bb_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/SliceKey.pub</td>
#       <td id="T_414bb_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/SliceKey</td>
#     </tr>
#     <tr>
#       <td id="T_414bb_row1_col0" class="data row1 col0" >413c7c93-31a1-4357-92f5-522038abd052</td>
#       <td id="T_414bb_row1_col1" class="data row1 col1" >C-2-1</td>
#       <td id="T_414bb_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_414bb_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_414bb_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_414bb_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_414bb_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_414bb_row1_col7" class="data row1 col7" >wash-w1.fabric-testbed.net</td>
#       <td id="T_414bb_row1_col8" class="data row1 col8" >WASH</td>
#       <td id="T_414bb_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_414bb_row1_col10" class="data row1 col10" >2001:400:a100:3020:f816:3eff:fe09:dd6e</td>
#       <td id="T_414bb_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_414bb_row1_col12" class="data row1 col12" ></td>
#       <td id="T_414bb_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/SliceKey -F /home/fab
# <style type="text/css">
# #T_8749a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_8749a th {
#   text-align: left;
# }
# #T_8749a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8749a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_8749a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8749a_row0_col0, #T_8749a_row0_col1, #T_8749a_row0_col2, #T_8749a_row0_col3, #T_8749a_row0_col4, #T_8749a_row0_col5, #T_8749a_row0_col6, #T_8749a_row0_col7, #T_8749a_row0_col8, #T_8749a_row1_col0, #T_8749a_row1_col1, #T_8749a_row1_col2, #T_8749a_row1_col3, #T_8749a_row1_col4, #T_8749a_row1_col5, #T_8749a_row1_col6, #T_8749a_row1_col7, #T_8749a_row1_col8, #T_8749a_row2_col0, #T_8749a_row2_col1, #T_8749a_row2_col2, #T_8749a_row2_col3, #T_8749a_row2_col4, #T_8749a_row2_col5, #T_8749a_row2_col6, #T_8749a_row2_col7, #T_8749a_row2_col8, #T_8749a_row3_col0, #T_8749a_row3_col1, #T_8749a_row3_col2, #T_8749a_row3_col3, #T_8749a_row3_col4, #T_8749a_row3_col5, #T_8749a_row3_col6, #T_8749a_row3_col7, #T_8749a_row3_col8, #T_8749a_row4_col0, #T_8749a_row4_col1, #T_8749a_row4_col2, #T_8749a_row4_col3, #T_8749a_row4_col4, #T_8749a_row4_col5, #T_8749a_row4_col6, #T_8749a_row4_col7, #T_8749a_row4_col8, #T_8749a_row5_col0, #T_8749a_row5_col1, #T_8749a_row5_col2, #T_8749a_row5_col3, #T_8749a_row5_col4, #T_8749a_row5_col5, #T_8749a_row5_col6, #T_8749a_row5_col7, #T_8749a_row5_col8, #T_8749a_row6_col0, #T_8749a_row6_col1, #T_8749a_row6_col2, #T_8749a_row6_col3, #T_8749a_row6_col4, #T_8749a_row6_col5, #T_8749a_row6_col6, #T_8749a_row6_col7, #T_8749a_row6_col8, #T_8749a_row7_col0, #T_8749a_row7_col1, #T_8749a_row7_col2, #T_8749a_row7_col3, #T_8749a_row7_col4, #T_8749a_row7_col5, #T_8749a_row7_col6, #T_8749a_row7_col7, #T_8749a_row7_col8, #T_8749a_row8_col0, #T_8749a_row8_col1, #T_8749a_row8_col2, #T_8749a_row8_col3, #T_8749a_row8_col4, #T_8749a_row8_col5, #T_8749a_row8_col6, #T_8749a_row8_col7, #T_8749a_row8_col8, #T_8749a_row9_col0, #T_8749a_row9_col1, #T_8749a_row9_col2, #T_8749a_row9_col3, #T_8749a_row9_col4, #T_8749a_row9_col5, #T_8749a_row9_col6, #T_8749a_row9_col7, #T_8749a_row9_col8, #T_8749a_row10_col0, #T_8749a_row10_col1, #T_8749a_row10_col2, #T_8749a_row10_col3, #T_8749a_row10_col4, #T_8749a_row10_col5, #T_8749a_row10_col6, #T_8749a_row10_col7, #T_8749a_row10_col8, #T_8749a_row11_col0, #T_8749a_row11_col1, #T_8749a_row11_col2, #T_8749a_row11_col3, #T_8749a_row11_col4, #T_8749a_row11_col5, #T_8749a_row11_col6, #T_8749a_row11_col7, #T_8749a_row11_col8, #T_8749a_row12_col0, #T_8749a_row12_col1, #T_8749a_row12_col2, #T_8749a_row12_col3, #T_8749a_row12_col4, #T_8749a_row12_col5, #T_8749a_row12_col6, #T_8749a_row12_col7, #T_8749a_row12_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_8749a">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_8749a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8749a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_8749a_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_8749a_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_8749a_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_8749a_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_8749a_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_8749a_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_8749a_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8749a_row0_col0" class="data row0 col0" >b6f255f4-708b-4cc7-a4f3-761297255cb0</td>
#       <td id="T_8749a_row0_col1" class="data row0 col1" >core-T-1-L-1</td>
#       <td id="T_8749a_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_8749a_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_8749a_row0_col4" class="data row0 col4" >WASH</td>
#       <td id="T_8749a_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_8749a_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_8749a_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_8749a_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row1_col0" class="data row1 col0" >d3871ffa-d2a4-46ea-9043-2aabd5f93a8e</td>
#       <td id="T_8749a_row1_col1" class="data row1 col1" >core-T-1-L-2</td>
#       <td id="T_8749a_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_8749a_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_8749a_row1_col4" class="data row1 col4" >WASH</td>
#       <td id="T_8749a_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_8749a_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_8749a_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_8749a_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row2_col0" class="data row2 col0" >7e38e6a4-ac33-49bf-a4ee-64f1030bd82b</td>
#       <td id="T_8749a_row2_col1" class="data row2 col1" >core-T-1-L-3</td>
#       <td id="T_8749a_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_8749a_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_8749a_row2_col4" class="data row2 col4" >WASH</td>
#       <td id="T_8749a_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_8749a_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_8749a_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_8749a_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row3_col0" class="data row3 col0" >ce1b4b61-e477-48e2-87ae-15c7dcefac08</td>
#       <td id="T_8749a_row3_col1" class="data row3 col1" >core-T-1-L-4</td>
#       <td id="T_8749a_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_8749a_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_8749a_row3_col4" class="data row3 col4" >WASH</td>
#       <td id="T_8749a_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_8749a_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_8749a_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_8749a_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row4_col0" class="data row4 col0" >9584c4d5-6dfe-429f-9bda-3e15b21b6114</td>
#       <td id="T_8749a_row4_col1" class="data row4 col1" >core-T-2-L-1</td>
#       <td id="T_8749a_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_8749a_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_8749a_row4_col4" class="data row4 col4" >WASH</td>
#       <td id="T_8749a_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_8749a_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_8749a_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_8749a_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row5_col0" class="data row5 col0" >1094dd8e-009e-49f3-8fa9-556bf6f36c7c</td>
#       <td id="T_8749a_row5_col1" class="data row5 col1" >core-T-2-L-2</td>
#       <td id="T_8749a_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_8749a_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_8749a_row5_col4" class="data row5 col4" >WASH</td>
#       <td id="T_8749a_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_8749a_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_8749a_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_8749a_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row6_col0" class="data row6 col0" >42b14fc5-d438-4b79-8439-2b11bcafbfb1</td>
#       <td id="T_8749a_row6_col1" class="data row6 col1" >core-T-2-L-3</td>
#       <td id="T_8749a_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_8749a_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_8749a_row6_col4" class="data row6 col
# <style type="text/css">
# #T_8749a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_8749a th {
#   text-align: left;
# }
# #T_8749a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8749a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_8749a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_8749a_row0_col0, #T_8749a_row0_col1, #T_8749a_row0_col2, #T_8749a_row0_col3, #T_8749a_row0_col4, #T_8749a_row0_col5, #T_8749a_row0_col6, #T_8749a_row0_col7, #T_8749a_row0_col8, #T_8749a_row1_col0, #T_8749a_row1_col1, #T_8749a_row1_col2, #T_8749a_row1_col3, #T_8749a_row1_col4, #T_8749a_row1_col5, #T_8749a_row1_col6, #T_8749a_row1_col7, #T_8749a_row1_col8, #T_8749a_row2_col0, #T_8749a_row2_col1, #T_8749a_row2_col2, #T_8749a_row2_col3, #T_8749a_row2_col4, #T_8749a_row2_col5, #T_8749a_row2_col6, #T_8749a_row2_col7, #T_8749a_row2_col8, #T_8749a_row3_col0, #T_8749a_row3_col1, #T_8749a_row3_col2, #T_8749a_row3_col3, #T_8749a_row3_col4, #T_8749a_row3_col5, #T_8749a_row3_col6, #T_8749a_row3_col7, #T_8749a_row3_col8, #T_8749a_row4_col0, #T_8749a_row4_col1, #T_8749a_row4_col2, #T_8749a_row4_col3, #T_8749a_row4_col4, #T_8749a_row4_col5, #T_8749a_row4_col6, #T_8749a_row4_col7, #T_8749a_row4_col8, #T_8749a_row5_col0, #T_8749a_row5_col1, #T_8749a_row5_col2, #T_8749a_row5_col3, #T_8749a_row5_col4, #T_8749a_row5_col5, #T_8749a_row5_col6, #T_8749a_row5_col7, #T_8749a_row5_col8, #T_8749a_row6_col0, #T_8749a_row6_col1, #T_8749a_row6_col2, #T_8749a_row6_col3, #T_8749a_row6_col4, #T_8749a_row6_col5, #T_8749a_row6_col6, #T_8749a_row6_col7, #T_8749a_row6_col8, #T_8749a_row7_col0, #T_8749a_row7_col1, #T_8749a_row7_col2, #T_8749a_row7_col3, #T_8749a_row7_col4, #T_8749a_row7_col5, #T_8749a_row7_col6, #T_8749a_row7_col7, #T_8749a_row7_col8, #T_8749a_row8_col0, #T_8749a_row8_col1, #T_8749a_row8_col2, #T_8749a_row8_col3, #T_8749a_row8_col4, #T_8749a_row8_col5, #T_8749a_row8_col6, #T_8749a_row8_col7, #T_8749a_row8_col8, #T_8749a_row9_col0, #T_8749a_row9_col1, #T_8749a_row9_col2, #T_8749a_row9_col3, #T_8749a_row9_col4, #T_8749a_row9_col5, #T_8749a_row9_col6, #T_8749a_row9_col7, #T_8749a_row9_col8, #T_8749a_row10_col0, #T_8749a_row10_col1, #T_8749a_row10_col2, #T_8749a_row10_col3, #T_8749a_row10_col4, #T_8749a_row10_col5, #T_8749a_row10_col6, #T_8749a_row10_col7, #T_8749a_row10_col8, #T_8749a_row11_col0, #T_8749a_row11_col1, #T_8749a_row11_col2, #T_8749a_row11_col3, #T_8749a_row11_col4, #T_8749a_row11_col5, #T_8749a_row11_col6, #T_8749a_row11_col7, #T_8749a_row11_col8, #T_8749a_row12_col0, #T_8749a_row12_col1, #T_8749a_row12_col2, #T_8749a_row12_col3, #T_8749a_row12_col4, #T_8749a_row12_col5, #T_8749a_row12_col6, #T_8749a_row12_col7, #T_8749a_row12_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_8749a">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_8749a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8749a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_8749a_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_8749a_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_8749a_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_8749a_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_8749a_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_8749a_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_8749a_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8749a_row0_col0" class="data row0 col0" >b6f255f4-708b-4cc7-a4f3-761297255cb0</td>
#       <td id="T_8749a_row0_col1" class="data row0 col1" >core-T-1-L-1</td>
#       <td id="T_8749a_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_8749a_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_8749a_row0_col4" class="data row0 col4" >WASH</td>
#       <td id="T_8749a_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_8749a_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_8749a_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_8749a_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row1_col0" class="data row1 col0" >d3871ffa-d2a4-46ea-9043-2aabd5f93a8e</td>
#       <td id="T_8749a_row1_col1" class="data row1 col1" >core-T-1-L-2</td>
#       <td id="T_8749a_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_8749a_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_8749a_row1_col4" class="data row1 col4" >WASH</td>
#       <td id="T_8749a_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_8749a_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_8749a_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_8749a_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row2_col0" class="data row2 col0" >7e38e6a4-ac33-49bf-a4ee-64f1030bd82b</td>
#       <td id="T_8749a_row2_col1" class="data row2 col1" >core-T-1-L-3</td>
#       <td id="T_8749a_row2_col2" class="data row2 col2" >L2</td>
#       <td id="T_8749a_row2_col3" class="data row2 col3" >L2Bridge</td>
#       <td id="T_8749a_row2_col4" class="data row2 col4" >WASH</td>
#       <td id="T_8749a_row2_col5" class="data row2 col5" >None</td>
#       <td id="T_8749a_row2_col6" class="data row2 col6" >None</td>
#       <td id="T_8749a_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_8749a_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row3_col0" class="data row3 col0" >ce1b4b61-e477-48e2-87ae-15c7dcefac08</td>
#       <td id="T_8749a_row3_col1" class="data row3 col1" >core-T-1-L-4</td>
#       <td id="T_8749a_row3_col2" class="data row3 col2" >L2</td>
#       <td id="T_8749a_row3_col3" class="data row3 col3" >L2Bridge</td>
#       <td id="T_8749a_row3_col4" class="data row3 col4" >WASH</td>
#       <td id="T_8749a_row3_col5" class="data row3 col5" >None</td>
#       <td id="T_8749a_row3_col6" class="data row3 col6" >None</td>
#       <td id="T_8749a_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_8749a_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row4_col0" class="data row4 col0" >9584c4d5-6dfe-429f-9bda-3e15b21b6114</td>
#       <td id="T_8749a_row4_col1" class="data row4 col1" >core-T-2-L-1</td>
#       <td id="T_8749a_row4_col2" class="data row4 col2" >L2</td>
#       <td id="T_8749a_row4_col3" class="data row4 col3" >L2Bridge</td>
#       <td id="T_8749a_row4_col4" class="data row4 col4" >WASH</td>
#       <td id="T_8749a_row4_col5" class="data row4 col5" >None</td>
#       <td id="T_8749a_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_8749a_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_8749a_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row5_col0" class="data row5 col0" >1094dd8e-009e-49f3-8fa9-556bf6f36c7c</td>
#       <td id="T_8749a_row5_col1" class="data row5 col1" >core-T-2-L-2</td>
#       <td id="T_8749a_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_8749a_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_8749a_row5_col4" class="data row5 col4" >WASH</td>
#       <td id="T_8749a_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_8749a_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_8749a_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_8749a_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_8749a_row6_col0" class="data row6 col0" >42b14fc5-d438-4b79-8439-2b11bcafbfb1</td>
#       <td id="T_8749a_row6_col1" class="data row6 col1" >core-T-2-L-3</td>
#       <td id="T_8749a_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_8749a_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_8749a_row6_col4" class="data row6 col

# %%
from infra_scripts.bgp.ClosGenerator import *
from ipaddress import ip_address, IPv4Address, IPv4Network
import re

COMPUTE_SUPERNET = "192.168.0.0/16"

# Iterate through every node in the topology
for node in topology.iterNodes():
    print(f"Configuring IPv4 addressing on node: {node}")

    # Pull IPv4 attribute data to configure FABRIC interfaces
    for neighbor, currentAddress in topology.getNodeAttribute(node, 'ipv4').items():
        # Access the interface from FABRIC.
        intfName = f"{node}-intf-{neighbor}-p1" # Naming is a bit strange, but is formatted in FABRIC as such.
        intf = slice.get_interface(intfName)

        # Convert the address and subnet into ipaddress objects for FABRIC processing.
        fabAddress = IPv4Address(currentAddress)
        fabSubnet = IPv4Network(f"{currentAddress}/24", strict=False)

        # Assign the address to the interface.
        intf.ip_addr_add(addr=fabAddress, subnet=fabSubnet)

    # For compute nodes, also add a compute supernet route with its attached leaf node as the next-hop.
    if(not topology.isNetworkNode(node)):
        IPGroup = re.search(r"192\.168\.([0-9]{1,3})\.[0-9]{1,3}", currentAddress) # Grab the third octet number.
        thirdOctet = IPGroup.group(1)
        nextHop = f"192.168.{thirdOctet}.254"

        # Add the route to the node
        intf.get_node().ip_route_add(subnet=IPv4Network(COMPUTE_SUPERNET), gateway=IPv4Address(nextHop))

        print(f"\tAdded route to {node}")

    print("\tConfiguration complete.")
# Out:
# Configuring IPv4 addressing on node: T-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: L-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: H-1
# 	Added route to H-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: L-2
# 	Configuration complete.
# Configuring IPv4 addressing on node: L-3
# 	Configuration complete.
# Configuring IPv4 addressing on node: L-4
# 	Configuration complete.
# Configuring IPv4 addressing on node: T-2
# 	Configuration complete.
# Configuring IPv4 addressing on node: C-1-1
# 	Added route to C-1-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: C-2-1
# 	Added route to C-2-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: C-3-1
# 	Added route to C-3-1
# 	Configuration complete.
# Configuring IPv4 addressing on node: C-4-1
# 	Added route to C-4-1
# 	Configuration complete.

# %% [markdown]
# ## <span style="color: #de4815"><b>Log Topology Information</b></span>

# %%
# Iterate through every node in the topology
for nodeName in topology.iterNodes():
    print(f"Saving {nodeName} SSH information...")
    tierNumber = topology.getNodeAttribute(nodeName, 'tier')
    logFile[f"tier_{tierNumber}"][nodeName]["ssh"] = manager.slice.get_node(nodeName).get_ssh_command()
# Out:
# Saving T-1 SSH information...
# Saving L-1 SSH information...
# Saving H-1 SSH information...
# Saving L-2 SSH information...
# Saving L-3 SSH information...
# Saving L-4 SSH information...
# Saving T-2 SSH information...
# Saving C-1-1 SSH information...
# Saving C-2-1 SSH information...
# Saving C-3-1 SSH information...
# Saving C-4-1 SSH information...

# %%
import json
with open(f'{SLICE_NAME}_k{PORTS_PER_DEVICE}_t{NUMBER_OF_TIERS}_BGP.json', "w") as outfile:
    json.dump(logFile, outfile)

# %% [markdown]
# ## To configure Hacker node - Working
# ## Run the slice cell at the top

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
    fablib.show_config()

except Exception as e:
    print(f"Exception: {e}")

# %%
from FabUtils import FabOrchestrator

# Make sure you have the manager imported.
try:
    manager = FabOrchestrator(SLICE_NAME)
except Exception as e:
    print(f"Exception: {e}")

# Upload the BGP scripts folder
manager.uploadDirectoryParallel("/home/fabric/work/NShenoy/FABRIC-Automation-main/remote_scripts/bgp_scripts", remoteLocation="/home/debian", prefixList=SEC_NODE_PREFIX)

manager.executeCommandsParallel('sudo chmod +x /home/debian/bgp_scripts/*.sh', prefixList=SEC_NODE_PREFIX)
# Run it
coreNodeConfig = "./bgp_scripts/init_bgp_Hacker.sh"
manager.executeCommandsParallel(coreNodeConfig, prefixList=SEC_NODE_PREFIX)
